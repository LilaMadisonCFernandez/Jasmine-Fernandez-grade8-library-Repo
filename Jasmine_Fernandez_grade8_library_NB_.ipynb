# %%
import requests
import json
url = "https://raw.githubusercontent.com/LilaMadisonCFernandez/Jasmine-Fernandez-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(url)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structure Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db
# Load the private key
cred = credentials.Certificate("/content/firebase_key.json")
# Initialize the app with your database URL
firebase_admin.initialize_app(cred, { "databaseURL": "https://jasmine-fernandez-librar-391b0-default-rtdb.asia-southeast1.firebasedatabase.app/"})
print("Firebase connected successfully!")
# Out:
# Firebase connected successfully!

# %%
import requests
import json

print("JSON file loaded")
ref = db.reference("books")
for book in books["books"]:
  ref.child(str(book["id"])).set(book)
print("Data uploaded successfully!")

num_books = len(books_data)
print(f"Total number of books in the library: {num_books}")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structure Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for books_id, info in books_data.items():
  print(info["title"])
# Out:
# Introduction to Python
# Data Structure Basics
# Web Development Essentials

# %%
for books_id, info in books_data.items():
  print(f"{info["title"]}: {info["details"]["available"]} available books")
# Out:
# Introduction to Python: 3 available books
# Data Structure Basics: 2 available books
# Web Development Essentials: 6 available books

# %%
num_books = len(books_data)
print(f"Total number of books in the library: {num_books}")
# Out:
# Total number of books in the library: 3
